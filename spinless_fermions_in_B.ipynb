# %%
import numpy as np
from quspin.operators import hamiltonian
from quspin.operators import quantum_LinearOperator
from scipy.sparse.linalg import eigsh
# Import the GENERAL basis for spinless fermions
from quspin.basis import spinless_fermion_basis_1d
import numpy as np
from quspin.operators import hamiltonian
from quspin.basis import spinless_fermion_basis_general
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
def map_double_index_to_single(i, j, Lx, Ly):
    if i < 0 or i >= Lx or j < 0 or j >= Ly:
        raise ValueError("Indices out of bounds")
    """Map a double index (i, j) to a single index in a flattened LxL array."""
    return j * Lx + i

def map_single_index_to_double(index, Lx, Ly):

    """Map a single index in a flattened LxL array back to a double index (i, j)."""
    i = index % Lx
    j = index // Lx
    return i, j

def calculate_density(vector, N_sites, basis_full): 
    """
    Correctly calculates the particle density using the hamiltonian.expt_value() 
    method for a symmetry-reduced basis.
    """

    densities = np.zeros(N_sites, dtype=np.float64)


    print("Calculating densities using hamiltonian.expt_value()...")
    
    # Iterate over every *physical site* j
    
    for j in range(N_sites):
        # 3. Define the local density operator "n_j"
        # This is "n" acting on site j.
        op_list = [["n", [[1.0, j]]]]

        n_j_op = hamiltonian(op_list, [],
                            basis=basis_full,
                            check_symm=False,
                            check_herm=False, check_pcon=False, dtype=np.float64) # 'n' is hermitian

        # 5. Calculate the expectation value
        #    This computes <psi_k | n_j | psi_k>
        density_at_j = n_j_op.expt_value(vector)
        
        # Ensure the value is real
        densities[j] = np.real(density_at_j)
    return densities

# %%
# QuSpin handles the fermionic signs internally.
def build_fermion_basis_with_translations(Lx, Ly, q, kx_prime_sector,ky_sector,  Nf):
    """
    Build a spinless fermion basis on a 2D Lx x Ly lattice with translation symmetries:
    """
    # Create 1D site-index array
    N=Lx * Ly
    sites = np.arange(N, dtype=np.int32)

    # Get (x,y) coordinates from 1D index (row-major mapping: s = x + y*Lx)
    x , y = map_single_index_to_double(sites, Lx, Ly)

    # Map 1: T_y -> (x, (y+1) % Ly)
    y_new = (y + 1) % Ly
    Ty_map = x + y_new * Lx 

    # Map 2: T_x^q -> ((x+q) % Lx, y)
    x_new = (x + q) % Lx
    Txq_map = x_new + y * Lx

    # --- 4. Create Symmetries Dictionary ---
    # The format is { "name": (map, sector) }
    symmetries = {
        "Txq": (Txq_map, kx_prime_sector),
        "Ty": (Ty_map, ky_sector)
    }

    # --- 5. Create the Basis ---
    # We use fermion_basis_general and the keyword Nf (number of fermions)
    print(f"Building basis for {Lx}x{Ly} spinless fermion lattice (N={Nf})")
    print(f"Using translation by q={q} in x-direction.")
    print(f"Sectors: ky = {ky_sector}, kx_prime = {kx_prime_sector}\n")
    
    basis = spinless_fermion_basis_general(N, Nf=Nf, **symmetries)

    print(f"\nTotal Hilbert space size (no symmetries): {2**N}")
    print(f"Reduced basis size (with symmetries): {basis.Ns}")
    return basis

def apply_rotation(kx, ky):
    """Apply the rotation symmetry (kx, ky) -> (-ky, kx)."""
    return (-ky % (Lx // q), kx % Ly)

def find_orbit(kx, ky):
    """Find the orbit of (kx, ky) under the rotation symmetry."""
    orbit = []
    current = (kx, ky)
    while current not in orbit:
        orbit.append(current)
        current = apply_rotation(*current)
    return orbit

# %%
def plot_ground_state_density(energy, ground_state, Lx, Ly, Nf, t, V, basis_full):
    '''
    Plots the electron density of the ground state(s).
    input: energy - array of eigenenergies, ground_state - 2D array of eigenvectors (columns) MUST BE IN THE FULL PCON BASIS,
           Lx, Ly - lattice dimensions, Nf - number of fermions,
           t - hopping amplitude, V - interaction strength,
           basis_full - full basis without symmetries for density calculation.
    '''
    ground_energy = energy[0]
    N_sites = Lx * Ly
    tolerance = 1e-6
    degenerate_indices = np.where(np.abs(energy - ground_energy) < tolerance)[0]
    degeneracy = len(degenerate_indices)
    
    print(f"Quantum Ground State Energy: {ground_energy:.6f}")
    if degeneracy > 1:
        print(f"The ground state is {degeneracy}-fold DEGENERATE.")
    else:
        print("The ground state is NOT degenerate.")


    for gs_idx, state_index in enumerate(degenerate_indices):
        gs_vector = ground_state[ :, state_index]

        density_2d = np.zeros((Lx, Ly))
        density_1d = calculate_density(gs_vector, N_sites, basis_full)
        for idx in range(len(density_1d)):
            x, y= map_single_index_to_double(idx, Lx, Ly)
            density_2d[x, y] = density_1d[idx]
        
        density_2d= density_2d.T # transpose for correct orientation in plot (python wokrs with (rows, columns))

        plt.style.use('seaborn-v0_8-whitegrid')
        fig, ax = plt.subplots(figsize=(8, 7))

        im = ax.imshow(density_2d, cmap='viridis', interpolation='nearest', origin='lower')

        cbar = fig.colorbar(im)
        cbar.set_label('Electron Density $\\langle n_i \\rangle$', fontsize=12)

        title = f'Ground State Electron Density ({Lx}x{Ly}, N={Nf}, T={t}, U={V})'
        if degeneracy > 1:
            title += f' - State {gs_idx+1} of {degeneracy}'
        ax.set_title(title, fontsize=14)
        ax.set_xlabel('Site x-index', fontsize=12)
        ax.set_ylabel('Site y-index', fontsize=12)
        ax.set_xticks(np.arange(Ly))
        ax.set_yticks(np.arange(Lx))

        # FIX: place text at (y, x) for cell [x, y]
        maxval = np.max(density_2d) if density_2d.size else 1.0
        for x in range(Lx):
            for y in range(Ly):
                value = density_2d[y, x]
                text_color = "black" if value > 0.5 * maxval else "white"
                ax.text(x, y, f'{value:.3f}', ha="center", va="center", color=text_color)

        plt.tight_layout()

        tiled_density = np.tile(density_2d, (5, 5))
        fig_tiled, ax_tiled = plt.subplots(figsize=(8, 7))
        im_tiled = ax_tiled.imshow(tiled_density, cmap='viridis', interpolation='nearest', origin='lower')

        cbar_tiled = fig_tiled.colorbar(im_tiled)
        cbar_tiled.set_label('Electron Density $\\langle n_i \\rangle$', fontsize=12)

        tiled_title = 'Tiled Density (Visualizing PBC)'
        if degeneracy > 1:
            tiled_title += f' - State {gs_idx+1} of {degeneracy}'
        ax_tiled.set_title(tiled_title, fontsize=14)

        for k in range(1, 5):  # draw more unit-cell gridlines in the 5x tiling
            ax_tiled.axhline(Lx * k - 0.5, color='white', linestyle='--', alpha=0.6)
            ax_tiled.axvline(Ly * k - 0.5, color='white', linestyle='--', alpha=0.6)

        ax_tiled.set_xticks([])
        ax_tiled.set_yticks([])
        plt.tight_layout()

# %%
def plot_energy_bands(energies_array, Lx, Ly, q, bands_number):
    """
    Plots energy bands as a function of ky for different kx sectors.
    input: energies_array: 3D numpy array with shape [Lx//q, Ly, bands_number]
    """

    # Variable to control whether to plot all kx or a single kx
    plot_all_kx = True  # Set to False to plot only a single kx value

    # Select a specific kx value to plot if plot_all_kx is False
    selected_kx = 0  # Change this to the desired kx value

    # Group data by kx
    data_by_kx = {kx: [] for kx in range(Lx // q)}

    for kx in range(Lx // q):
        for ky in range(Ly):
            energies = []
            for i in range(bands_number):
                energies.append(energies_array[kx, ky, i])
            data_by_kx[kx].append((ky, energies))

    # --- Plotting ---
    print("Plotting the energy bands...")
    fig, ax = plt.subplots(figsize=(12, 8))

    # Use a colormap to assign distinct colors for each kx and band index
    colormap = plt.cm.get_cmap('rainbow', Lx // q * bands_number)  # Unique colors for each kx and band

    # Determine which kx sectors to plot
    kx_sectors_to_plot = sorted(data_by_kx.keys()) if plot_all_kx else [selected_kx]

    # Loop through the selected kx sectors to plot their bands
    for kx_sector in kx_sectors_to_plot:
        data = data_by_kx[kx_sector]
        
        # Sort the data by the ky value to ensure the lines are drawn correctly
        data.sort(key=lambda item: item[0])
        
        # Unzip the sorted data into ky values and lists of energy levels
        kys, energy_levels_list = zip(*data)
        
        # Transpose the list of energy levels to group them by band index
        # This turns [[E_ky0_band0, E_ky0_band1], [E_ky1_band0, E_ky1_band1]]
        # into [[E_ky0_band0, E_ky1_band0], [E_ky0_band1, E_ky1_band1]]
        bands = np.array(energy_levels_list).T

        # Plot each individual energy band for the current kx
        for band_idx, band_energies in enumerate(bands):
            # Assign a unique color for each kx and band index
            color_idx = kx_sector * bands_number + band_idx
            color = colormap(color_idx)

            # Add a label for each kx_sector and band
            label = f'$k_x = {kx_sector}, \, \mathrm{{Band}} \, {band_idx + 1}$' if plot_all_kx else f'Band {band_idx + 1}'
            ax.plot(kys, band_energies, marker='o', linestyle='-', color=color, label=label)

    # --- Final Plot Styling ---
    ax.set_xlabel('$k_y$ sector', fontsize=14)
    ax.set_ylabel('Energy', fontsize=14)
    ax.set_title('Energy Bands vs. $k_y$ for different $k_x$ sectors', fontsize=16)

    # Set integer ticks on the axes to match the k-sectors
    ax.set_xticks(range(Ly))
    ax.set_xticklabels([f'{i}' for i in range(Ly)])

    # Adjust the legend based on whether all kx are plotted
    if plot_all_kx:
        ax.legend(title='Energy Bands and $k_x$ Sectors', fontsize=10, loc='upper left', bbox_to_anchor=(1, 1))
    else:
        ax.legend(title='Energy Bands', fontsize=10, loc='upper left', bbox_to_anchor=(1, 1))

    ax.grid(True, linestyle='--', alpha=0.6)

    plt.tight_layout()
    plt.show()
# Out:
# <>:55: SyntaxWarning: invalid escape sequence '\,'
# <>:55: SyntaxWarning: invalid escape sequence '\,'
# <>:55: SyntaxWarning: invalid escape sequence '\,'
# <>:55: SyntaxWarning: invalid escape sequence '\,'
# /var/folders/z4/q3_z78fj4gldz7hpcmkdj1y00000gn/T/ipykernel_14402/3712138174.py:55: SyntaxWarning: invalid escape sequence '\,'
#   label = f'$k_x = {kx_sector}, \, \mathrm{{Band}} \, {band_idx + 1}$' if plot_all_kx else f'Band {band_idx + 1}'
# /var/folders/z4/q3_z78fj4gldz7hpcmkdj1y00000gn/T/ipykernel_14402/3712138174.py:55: SyntaxWarning: invalid escape sequence '\,'
#   label = f'$k_x = {kx_sector}, \, \mathrm{{Band}} \, {band_idx + 1}$' if plot_all_kx else f'Band {band_idx + 1}'

# %%
def plot_lowest_eigenvalues_vs_V(lowest_eigenvalues_by_V, bands_number):  
    """
    Plots the lowest eigenvalues as a function of interaction strength V.
    input: dictionary lowest_eigenvalues_by_V
    """
    # --- Plotting the Lowest Eigenvalues vs. V ---
    print("Plotting the lowest eigenvalues vs. V...")
    fig, ax = plt.subplots(figsize=(12, 8))

    # Use a colormap to assign distinct colors for each eigenvalue index
    colors = plt.cm.tab10(np.linspace(0, 1, bands_number))  # Use a high-contrast colormap

    # Define a list of distinct markers and line styles
    markers = ['o', 's', '^', 'd', 'v', 'p', '*', 'h', 'x', '+']  # Add more if needed
    line_styles = ['-', '--', '-.', ':']  # Cycle through line styles

    # Transpose the data to group eigenvalues by index
    V_list = list(lowest_eigenvalues_by_V.keys())
    eigenvalues_by_index = list(zip(*lowest_eigenvalues_by_V.values()))  # Transpose the dictionary values
    num_eigenvalues = len(eigenvalues_by_index)

    # Plot each eigenvalue index as a function of V
    for i, eigenvalues in enumerate(eigenvalues_by_index):
        ax.plot(
            V_list, eigenvalues, 
            marker=markers[i % len(markers)],  # Cycle through markers
            linestyle=line_styles[i % len(line_styles)],  # Cycle through line styles
            color=colors[i], 
            label=f' {i + 1}', 
            alpha=0.9,  # Slightly increase alpha for better visibility
            linewidth=1.5  # Make lines slightly thicker
        )

        # Add labels directly near the end of the lines with unique vertical offsets
        vertical_offset = (i) * 0.1 -0.8   # Alternate offsets: +0.1, -0.1
        horizontal_offset = i*0.1-0.2
        ax.text(
            V_list[-1] + 0.1, #+horizontal_offset,  # Slightly offset to the right of the last V value
            eigenvalues[-1] + vertical_offset,  # Add unique vertical offset
            f' {i + 1}', 
            fontsize=10, 
            color=colors[i], 
            va='center'
        )

    # Adjust x-axis limits to make space for the labels
    ax.set_xlim([min(V_list), max(V_list) + 1])

    # Adjust y-axis limits to ensure all labels are visible
    all_energies = [e for eigenvalues in eigenvalues_by_index for e in eigenvalues]
    ax.set_ylim([min(all_energies) - 1, max(all_energies) + 1])

    # --- Final Plot Styling ---
    ax.set_xlabel('$V$', fontsize=14)
    ax.set_ylabel('Energy', fontsize=14)
    ax.set_title('Lowest Eigenvalues vs. $V$ (Across All $k$-Sectors)', fontsize=16)

    # Add gridlines for better readability
    ax.grid(True, linestyle='--', alpha=0.6)

    # Adjust the x-axis limits to make space for the labels
    ax.set_xlim([min(V_list), max(V_list) + 1])

    plt.tight_layout()
    plt.show()

# %%
def find_lowest_energies_per_k_sector(Lx, Ly, Nf, t, V, p, q ,kx_sector, ky_sector,  perturbation=False, vec_number=4):
    """
    Finds the lowest energy eigenvalues and corresponding eigenvectors
    input: Lx, Ly: lattice dimensions, Nf: number of fermions,t: hopping amplitude,V: interaction strength,p, q: flux parameters,kx_sector, ky_sector: momentum sectors
           kx_sector in [0, Lx/q-1], ky_sector in [0, Ly-1], perturbation: bool to add small perturbation to break degeneracy, vec_number: number of eigenvalues/vectors to compute
    output: energy eigenvalues, eigenvectors, basis used
    """
    basis= build_fermion_basis_with_translations(Lx, Ly, q, kx_sector, ky_sector, Nf)
    if p==0 or q==1: ###IMPLEMENT; READ DOCUMENTATOIN  FOR IMPROVEMENT
        type=np.float64
    else:
        type=np.complex128

    if Lx % q != 0:
        raise ValueError("For periodic boundary conditions, q must be a multiple of Lx.")
    # -- Set up the 2D lattice sites for periodic boundary conditions --
    # The site indices 'i' map the 2D lattice to a 1D array of sites,
    # which is how QuSpin's general basis handles arbitrary geometries.

    # x-direction bonds
    hop_x_dx = [[-t, map_double_index_to_single((i+1) % Lx ,j,Lx, Ly), map_double_index_to_single(i,j,Lx, Ly) ] for i in range(Lx) for j in range(Ly)]
    hop_x_sx = [[-t, map_double_index_to_single(i ,j,Lx, Ly), map_double_index_to_single((i+1) % Lx,j,Lx, Ly) ] for i in range(Lx) for j in range(Ly)] 
    int_x = [[V, map_double_index_to_single((i+1) % Lx ,j,Lx, Ly), map_double_index_to_single(i,j,Lx,Ly) ] for i in range(Lx) for j in range(Ly)]

    # y-direction bonds
    hop_y_dx = [[-t*np.exp(-2j * p * np.pi * i / q), map_double_index_to_single(i ,(j+1) % Ly,Lx,Ly), map_double_index_to_single(i,j,Lx,Ly) ] for i in range(Lx) for j in range(Ly)]
    hop_y_sx = [[-t*np.exp(2j * p * np.pi * i / q), map_double_index_to_single(i ,j,Lx,Ly), map_double_index_to_single(i,(j+1) % Ly,Lx,Ly) ] for i in range(Lx) for j in range(Ly)]
    int_y = [[V, map_double_index_to_single(i ,(j+1) % Ly,Lx,Ly), map_double_index_to_single(i,j,Lx,Ly) ] for i in range(Lx) for j in range(Ly)]


    # -- Set up the basis --
    # Use the general basis for any lattice geometry.
    # It only needs the total number of sites (N_sites) and particle number (Nf).

    print(f"Hilbert space size for {Lx}x{Ly} lattice and Nf={Nf} fermions: {basis.Ns} states")

    # -- Define Hamiltonian operators --
    # The static list now includes terms for both x and y directions.
    # The operator string "-+" is QuSpin's notation for the Hermitian conjugate
    # of the "+-" operator, ensuring the Hamiltonian is Hermitian.
    kinetic_part = [["+-", hop_x_dx], ["+-", hop_x_sx],["+-", hop_y_dx], ["+-", hop_y_sx]]
    potential_part = [["nn", int_x], ["nn", int_y]]
    
    #try to break degeneracy due to finite size
    if perturbation:
        eps = 1e-5
        epsilon_term = [[eps*(-1)**(i), map_double_index_to_single(i,j,Lx,Ly) ] for i in range(Lx) for j in range(Ly)]
        # epsilon_term = [[-eps, map_double_index_to_single(0,0,L)]]
        force_degeneracy = [["n", epsilon_term]]
        static_list = kinetic_part + potential_part + force_degeneracy
    else:
        static_list = kinetic_part + potential_part


    # -- Construct the Hamiltonian object --
    # This part is the same, but now it uses the 2D-compatible general basis.
    H = hamiltonian(static_list, [], basis=basis, dtype=np.complex128,
                check_herm=False, check_symm=False)

    print("Hamiltonian built")
    # -- Find the Ground State using Lanczos Algorithm --
    # We can use a deterministic starting vector for reproducible results.
    print("\nFinding ground state using Lanczos method...")
    v0 = np.ones(basis.Ns, dtype=np.complex128)
    v0 /= np.linalg.norm(v0)

    # The eigsh call finds the lowest eigenvalue ("SA" = Smallest Algebraic)
    # and its corresponding eigenvector.
    energy, ground_state = H.eigsh(k=vec_number, which="SA")#, v0=v0)
    #energy, ground_state = H.eigh()
    print(f"\nGround state energy for 2D system:", energy)

    return energy, ground_state, basis

# %%
def find_lowest_energies_across_all_sectors(Lx, Ly, Nf, t, V, p, q, bands_number):
    """
    inputs: Lx, Ly, Nf, t, V, p, q, bands_number (number of bands to consider for each diagonalization)
    outputs: array [kx, ky, band_index] = energy, list of tuples (energy, kx_sector, ky_sector, band_index) in ascending order,
             list of energies in ascending order, array (kx_sector, ky_sector, band_index, state component), lowest energy states in ascending order
    """

    energy_bands = []  # To store (kx_sector, ky_sector, ground_energy) tuples
    energies_array = np.empty((Lx // q, Ly, bands_number), dtype=np.complex128)
    visited = set()  # To keep track of visited (kx, ky) pairs

    for kx_sector in range(Lx // q):
        for ky_sector in range(Ly):
            if (kx_sector, ky_sector) not in visited:
                # Find the orbit of the current (kx, ky) pair
                orbit = find_orbit(kx_sector, ky_sector)

                # Mark all pairs in the orbit as visited
                visited.update(orbit)

                # Use the first pair in the orbit as the representative
                representative_kx, representative_ky = orbit[0]

                # Compute the eigenvalues and eigenstates for the representative
                energy, ground_state, basis = find_lowest_energies_per_k_sector(
                    Lx, Ly, Nf, t, V, p=p, q=q, kx_sector=representative_kx, ky_sector=representative_ky,
                    perturbation=False, vec_number=bands_number
                )

                # Assign the computed values to all pairs in the orbit
                for kx, ky in orbit:
                    energy_bands.append((kx, ky, energy))
                    for i, e in enumerate(energy):
                        energies_array[kx, ky, i] = e

    # Flatten the energies for sorting
    flattened_energies = []
    for kx_sector, ky_sector, energy_array in energy_bands:
        for i, energy in enumerate(energy_array):
            flattened_energies.append((energy, kx_sector, ky_sector, i))  # Store energy with its indices

    # Sort the flattened energies and reorder the states accordingly
    sorted_energies = sorted(flattened_energies, key=lambda x: x[0])  # Sort by energy

    # Extract the sorted energy values and their corresponding states
    sorted_energy_values = [e[0] for e in sorted_energies]  # Extract only the energy values

    return energies_array, sorted_energies, sorted_energy_values

# %%
def get_lowest_eigenvalues_vs_V(Lx, Ly, Nf, t, p, q, V_min, V_max, num_V_points, bands_number, across_all_sectors=True, kx=0, ky=0, eigenvalues_to_plot=10):
    """
    Computes the lowest eigenvalues as a function of interaction strength V.
    inputs: Lx, Ly, Nf, t, p, q, V_min, V_max, num_V_points, bands_number, across_all_sectors (bool), kx_sector, ky_sector
    outputs: dictionary with V as keys and list of lowest eigenvalues as values
    """
    # Adjust this to plot more or fewer eigenvalues

    V_values = np.linspace(V_min, V_max, num_V_points)
    # Initialize a dictionary to store sorted eigenvalues for each V
    lowest_eigenvalues_by_V = {V: [] for V in V_values}

    print(f"Starting computation for {num_V_points} values of V...")
    for idx, V in enumerate(V_values):
        print(f"Processing V={V:.2f} ({idx + 1}/{num_V_points})...")
        sorted_energy_values = []
        if across_all_sectors:
            _, __, sorted_energy_values = find_lowest_energies_across_all_sectors(Lx, Ly, Nf, t, V, p, q, bands_number)
        else:
            energy, _, _ = find_lowest_energies_per_k_sector(Lx, Ly, Nf, t, V, p, q, kx, ky, perturbation=False, vec_number=bands_number)
            sorted_energy_values = sorted(energy)[:eigenvalues_to_plot]
        # Store the lowest eigenvalues in the dictionary
        lowest_eigenvalues_by_V[V] = sorted_energy_values[:eigenvalues_to_plot]

    print("Computation complete.")
    return lowest_eigenvalues_by_V

# %%
Lx=4 # Total number of sites
Ly=4
Nf = 4 #N_sites // 2 # Number of fermions (half-filling)
N_sites = Lx * Ly
p=0
q=1
bands_number=2
t = 1.0      # Hopping strength
V = 2000.0      # Interaction strength


#bands_number=basis_full.Ns
energies_array, sorted_energies, sorted_energy_values = find_lowest_energies_across_all_sectors(Lx, Ly, Nf, t, V, p, q, bands_number)
# Out:
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 0, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 116
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 116 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-2.83242553 -2.00549881]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-4.90510208 -2.45398711]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-4.90430659 -2.83242553]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-3.46993301 -2.00549881]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-2.83279917 -2.45398711]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 2
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-4.90430659 -3.46993301]

# %%
kx_values = np.arange(Lx // q)  # Integer values for kx sectors
ky_values = np.arange(Ly)  # Integer values for ky sectors
energies = []

# Collect energies for the lowest band (index 0)
for kx in range(Lx // q):
    for ky in range(Ly):
        energies.append(energies_array[kx, ky, 0])  # Taking the lowest band (index 0)

# Plot the energy bands
plt.figure(figsize=(8, 6))
sc = plt.scatter(
    np.repeat(kx_values, Ly),  # Repeat kx_values for each ky
    np.tile(ky_values, Lx // q),  # Tile ky_values for each kx
    c=energies, cmap='viridis', s=100
)
plt.colorbar(sc, label='Ground State Energy')
plt.title('Energy Bands for Different Momentum Sectors')
plt.xlabel('$k_x$ Sector')
plt.ylabel('$k_y$ Sector')
plt.xticks(range(Lx // q))
plt.yticks(range(Ly))
plt.grid(True)
plt.show()

# Find the minimum energy and its corresponding sector
min_energy = min(energies)
min_index = energies.index(min_energy)
kx_min = min_index // Ly  # Integer division to get kx index
ky_min = min_index % Ly  # Modulo to get ky index
print("Total ground state is in ", min_energy, " and is in sector", kx_min, ky_min)
# Out:
# /Users/massimodicosimo/miniconda3/envs/physics_3.12/lib/python3.12/site-packages/matplotlib/cbook.py:1719: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /Users/massimodicosimo/miniconda3/envs/physics_3.12/lib/python3.12/site-packages/matplotlib/axes/_axes.py:4733: ComplexWarning: Casting complex values to real discards the imaginary part
#   c = np.asanyarray(c, dtype=float)
# Total ground state is in  (-4.905102076272552+0j)  and is in sector 0 1

# %%
plot_energy_bands(energies_array, Lx, Ly, q, bands_number)
# Out:
# Plotting the energy bands...
# /var/folders/z4/q3_z78fj4gldz7hpcmkdj1y00000gn/T/ipykernel_14402/3712138174.py:28: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colormap = plt.cm.get_cmap('rainbow', Lx // q * bands_number)  # Unique colors for each kx and band
# /Users/massimodicosimo/miniconda3/envs/physics_3.12/lib/python3.12/site-packages/matplotlib/cbook.py:1355: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
Lx=4 # Total number of sites
Ly=4
Nf = 4 #N_sites // 2 # Number of fermions (half-filling)
N_sites = Lx * Ly
p=0
q=1
t = 1.0      # Hopping strength
V = 1.0      # Interaction strength
V_min = 00.0
V_max = 200.0
num_V_points = 20
bands_number = 2
eigenvalues_to_plot = 30
basis_full = spinless_fermion_basis_general(N_sites, Nf=Nf)
lowest_eigenvalues_by_V = get_lowest_eigenvalues_vs_V(Lx, Ly, Nf, t, p, q, V_min=V_min, V_max=V_max, num_V_points=num_V_points, bands_number=bands_number , across_all_sectors=True, eigenvalues_to_plot=eigenvalues_to_plot)
# Out:
# Starting computation for 20 values of V...
# Processing V=0.00 (1/20)...
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 0, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 116
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 116 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-8. -8.]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-10.  -6.]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-8. -8.]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-8. -8.]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-6. -6.]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 2
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-8. -8.]
# Processing V=10.53 (2/20)...
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 0, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 116
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 116 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-3.53506159 -2.9915062 ]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-5.97334684 -3.20567743]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-5.70497434 -3.53506159]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-4.47531063 -2.9915062 ]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-3.5448614  -3.20567743]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 2
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-5.70497434 -4.47531063]
# Processing V=21.05 (3/20)...
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 0, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 116
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 116 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-3.19471433 -2.51019333]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-5.45930064 -2.85271066]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-5.35087062 -3.19471433]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-3.99711792 -2.51019333]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-3.21585303 -2.85271066]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 2
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-5.35087062 -3.99711792]
# Processing V=31.58 (4/20)...
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 0, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 116
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 116 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-3.07558714 -2.34306904]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-5.2773371  -2.72377762]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-5.21209455 -3.07558714]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-3.82467448 -2.34306904]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-3.09315127 -2.72377762]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 2
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-5.21209455 -3.82467448]
# Processing V=42.11 (5/20)...
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 0, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 116
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 116 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-3.01492919 -2.25835271]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-5.18453475 -2.6572359 ]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-5.13837037 -3.01492919]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-3.73634765 -2.25835271]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-3.02934902 -2.6572359 ]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 2
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-5.13837037 -3.73634765]
# Processing V=52.63 (6/20)...
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 0, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 116
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 116 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-2.97817793 -2.20717158]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-5.12828067 -2.61665531]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-5.09270103 -2.97817793]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-3.68273179 -2.20717158]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-2.99029349 -2.61665531]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 2
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-5.09270103 -3.68273179]
# Processing V=63.16 (7/20)...
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 0, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 116
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 116 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-2.95352676 -2.17290929]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-5.09054027 -2.58933052]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-5.06164784 -2.95352676]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-3.6467428  -2.17290929]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-2.96393764 -2.58933052]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 2
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-5.06164784 -3.6467428 ]
# Processing V=73.68 (8/20)...
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 0, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 116
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 116 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-2.93584451 -2.14836855]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-5.06346648 -2.5696807 ]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-5.03916724 -2.93584451]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-3.62092056 -2.14836855]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-2.9449573 -2.5696807]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 2
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-5.03916724 -3.62092056]
# Processing V=84.21 (9/20)...
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 0, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 116
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 116 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-2.92254194 -2.12992666]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-5.04309747 -2.55487133]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-5.02214204 -2.92254194]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-3.6014922  -2.12992666]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-2.93063806 -2.55487133]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 2
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-5.02214204 -3.6014922 ]
# Processing V=94.74 (10/20)...
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 0, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 116
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 116 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-2.91217115 -2.11556174]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-5.02721714 -2.54331037]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-5.00880228 -2.91217115]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-3.58634541 -2.11556174]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-2.91945139 -2.54331037]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 2
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-5.00880228 -3.58634541]
# Processing V=105.26 (11/20)...
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 0, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 116
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 116 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-2.90385912 -2.10405658]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-5.01448905 -2.53403484]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-4.99806862 -2.90385912]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-3.57420576 -2.10405658]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-2.91047104 -2.53403484]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 2
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-4.99806862 -3.57420576]
# Processing V=115.79 (12/20)...
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 0, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 116
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 116 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-2.89704816 -2.09463461]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-5.00405941 -2.5264281 ]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-4.98924557 -2.89704816]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-3.56425881 -2.09463461]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-2.90310306 -2.5264281 ]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 2
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-4.98924557 -3.56425881]
# Processing V=126.32 (13/20)...
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 0, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 116
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 116 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-2.89136531 -2.08677706]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-4.99535719 -2.52007701]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-4.98186484 -2.89136531]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-3.55595983 -2.08677706]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-2.89694907 -2.52007701]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 2
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-4.98186484 -3.55595983]
# Processing V=136.84 (14/20)...
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 0, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 116
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 116 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-2.88655174 -2.08012419]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-4.98798607 -2.5146944 ]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-4.97559956 -2.88655174]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-3.54893066 -2.08012419]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-2.89173195 -2.5146944 ]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 2
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-4.97559956 -3.54893066]
# Processing V=147.37 (15/20)...
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 0, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 116
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 116 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-2.88242215 -2.07441872]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-4.98166233 -2.51007446]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-4.9702147  -2.88242215]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-3.54290063 -2.07441872]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-2.88725293 -2.51007446]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 2
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-4.9702147  -3.54290063]
# Processing V=157.89 (16/20)...
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 0, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 116
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 116 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-2.87884044 -2.06947172]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-4.97617756 -2.50606584]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-4.96553689 -2.87884044]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-3.53767088 -2.06947172]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-2.88336573 -2.50606584]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 2
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-4.96553689 -3.53767088]
# Processing V=168.42 (17/20)...
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 0, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 116
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 116 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-2.87570435 -2.0651414 ]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-4.97137519 -2.50255472]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-4.96143547 -2.87570435]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-3.53309202 -2.0651414 ]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-2.87996035 -2.50255472]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 2
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-4.96143547 -3.53309202]
# Processing V=178.95 (18/20)...
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 0, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 116
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 116 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-2.87293559 -2.06131921]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-4.96713531 -2.49945392]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-4.95781011 -2.87293559]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-3.52904967 -2.06131921]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-2.87695245 -2.49945392]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 2
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-4.95781011 -3.52904967]
# Processing V=189.47 (19/20)...
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 0, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 116
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 116 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-2.87047319 -2.05792068]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-4.96336457 -2.49669547]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-4.95458249 -2.87047319]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-3.52545476 -2.05792068]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-2.87427627 -2.49669547]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 2
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-4.95458249 -3.52545476]
# Processing V=200.00 (20/20)...
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 0, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 116
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 116 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-2.86826897 -2.05487907]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-4.95998919 -2.49422566]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 0
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-4.95169055 -2.86826897]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 1, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-3.5222369  -2.05487907]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 1
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 112
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 112 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-2.87187982 -2.49422566]
# Building basis for 4x4 spinless fermion lattice (N=4)
# Using translation by q=1 in x-direction.
# Sectors: ky = 2, kx_prime = 2
#
#
# Total Hilbert space size (no symmetries): 65536
# Reduced basis size (with symmetries): 120
# Hilbert space size for 4x4 lattice and Nf=4 fermions: 120 states
# Particle conservation check passed!
# Hamiltonian built
#
# Finding ground state using Lanczos method...
#
# Ground state energy for 2D system: [-4.95169055 -3.5222369 ]
# Computation complete.

# %%
plot_lowest_eigenvalues_vs_V(lowest_eigenvalues_by_V, bands_number=eigenvalues_to_plot)
# Out:
# Plotting the lowest eigenvalues vs. V...

# %%
##print lowest_eigenvalues_by_V


print("Lowest eigenvalues vs V:")
for V, energies in lowest_eigenvalues_by_V.items():
    energies_str = ', '.join(f'{energy:.16f}' for energy in energies)  # Use .16f for 16 digits
    print(f"V={V:.2f}: Energies: {energies_str}")
# Out:
# Lowest eigenvalues vs V:
# V=0.00: Energies: -10.0000000000000178, -10.0000000000000178, -10.0000000000000178, -10.0000000000000178, -8.0000000000000124, -8.0000000000000071, -8.0000000000000071, -8.0000000000000053, -8.0000000000000053, -8.0000000000000036, -8.0000000000000036, -8.0000000000000036, -8.0000000000000036, -8.0000000000000036, -8.0000000000000036, -8.0000000000000036, -8.0000000000000036, -8.0000000000000036, -8.0000000000000000, -8.0000000000000000, -6.0000000000000115, -6.0000000000000115, -6.0000000000000115, -6.0000000000000115, -6.0000000000000027, -6.0000000000000027, -6.0000000000000027, -6.0000000000000027, -5.9999999999999991, -5.9999999999999991, -5.9999999999999991, -5.9999999999999991
# V=10.53: Energies: -5.9733468411379063, -5.9733468411379063, -5.9733468411379063, -5.9733468411379063, -5.7049743429853894, -5.7049743429853894, -5.7049743429853645, -4.4753106273857997, -4.4753106273857890, -4.4753106273857890, -4.4753106273857890, -4.4753106273857890, -3.5448613957807962, -3.5448613957807962, -3.5448613957807962, -3.5448613957807962, -3.5350615909729264, -3.5350615909729264, -3.5350615909729117, -3.2056774316780068, -3.2056774316780068, -3.2056774316780068, -3.2056774316780068, -3.2056774316780059, -3.2056774316780059, -3.2056774316780059, -3.2056774316780059, -2.9915062027422450, -2.9915062027422428, -2.9915062027422428, -2.9915062027422428, -2.9915062027422428
# V=21.05: Energies: -5.4593006428921678, -5.4593006428921678, -5.4593006428921678, -5.4593006428921678, -5.3508706230270127, -5.3508706230270127, -5.3508706230269949, -3.9971179197061373, -3.9971179197061373, -3.9971179197061373, -3.9971179197061373, -3.9971179197061275, -3.2158530337589681, -3.2158530337589681, -3.2158530337589681, -3.2158530337589681, -3.1947143265373916, -3.1947143265373916, -3.1947143265373708, -2.8527106635244199, -2.8527106635244199, -2.8527106635244199, -2.8527106635244199, -2.8527106635243813, -2.8527106635243813, -2.8527106635243813, -2.8527106635243813, -2.5101933345611931, -2.5101933345611664, -2.5101933345611664, -2.5101933345611664, -2.5101933345611664
# V=31.58: Energies: -5.2773371026576132, -5.2773371026576132, -5.2773371026576132, -5.2773371026576132, -5.2120945543804664, -5.2120945543804664, -5.2120945543804424, -3.8246744776876453, -3.8246744776876418, -3.8246744776876418, -3.8246744776876418, -3.8246744776876418, -3.0931512733955300, -3.0931512733955300, -3.0931512733955300, -3.0931512733955300, -3.0755871350918969, -3.0755871350918969, -3.0755871350918760, -2.7237776172875341, -2.7237776172875341, -2.7237776172875341, -2.7237776172875341, -2.7237776172875168, -2.7237776172875168, -2.7237776172875168, -2.7237776172875168, -2.3430690426544860, -2.3430690426544531, -2.3430690426544531, -2.3430690426544531, -2.3430690426544531
# V=42.11: Energies: -5.1845347517657556, -5.1845347517657556, -5.1845347517657556, -5.1845347517657556, -5.1383703701134520, -5.1383703701134520, -5.1383703701134227, -3.7363476524772077, -3.7363476524772032, -3.7363476524772032, -3.7363476524772032, -3.7363476524772032, -3.0293490186581717, -3.0293490186581717, -3.0293490186581717, -3.0293490186581717, -3.0149291894219621, -3.0149291894219621, -3.0149291894218928, -2.6572359000803285, -2.6572359000803285, -2.6572359000803285, -2.6572359000803285, -2.6572359000802903, -2.6572359000802903, -2.6572359000802903, -2.6572359000802903, -2.2583527073005003, -2.2583527073005003, -2.2583527073005003, -2.2583527073005003, -2.2583527073004981
# V=52.63: Energies: -5.1282806715524725, -5.1282806715524725, -5.1282806715524725, -5.1282806715524725, -5.0927010284328258, -5.0927010284328258, -5.0927010284327938, -3.6827317895648135, -3.6827317895648068, -3.6827317895648068, -3.6827317895648068, -3.6827317895648068, -2.9902934946085327, -2.9902934946085327, -2.9902934946085327, -2.9902934946085327, -2.9781779330141731, -2.9781779330141731, -2.9781779330141140, -2.6166553070959009, -2.6166553070959009, -2.6166553070959009, -2.6166553070959009, -2.6166553070958365, -2.6166553070958365, -2.6166553070958365, -2.6166553070958365, -2.2071715800552592, -2.2071715800552592, -2.2071715800552592, -2.2071715800552592, -2.2071715800551783
# V=63.16: Energies: -5.0905402732264893, -5.0905402732264893, -5.0905402732264893, -5.0905402732264893, -5.0616478360862036, -5.0616478360862036, -5.0616478360861175, -3.6467427951257028, -3.6467427951256366, -3.6467427951256366, -3.6467427951256366, -3.6467427951256366, -2.9639376391299321, -2.9639376391299321, -2.9639376391299321, -2.9639376391299321, -2.9535267592273149, -2.9535267592273149, -2.9535267592272456, -2.5893305170825709, -2.5893305170825709, -2.5893305170825709, -2.5893305170825709, -2.5893305170825118, -2.5893305170825118, -2.5893305170825118, -2.5893305170825118, -2.1729092877325136, -2.1729092877324927, -2.1729092877324927, -2.1729092877324927, -2.1729092877324927
# V=73.68: Energies: -5.0634664847805588, -5.0634664847805588, -5.0634664847805588, -5.0634664847805588, -5.0391672386241426, -5.0391672386241426, -5.0391672386241222, -3.6209205627632470, -3.6209205627632470, -3.6209205627632470, -3.6209205627632470, -3.6209205627631955, -2.9449573036237271, -2.9449573036237271, -2.9449573036237271, -2.9449573036237271, -2.9358445074273476, -2.9358445074273476, -2.9358445074273050, -2.5696806992566494, -2.5696806992566494, -2.5696806992566494, -2.5696806992566494, -2.5696806992565988, -2.5696806992565988, -2.5696806992565988, -2.5696806992565988, -2.1483685527202585, -2.1483685527202585, -2.1483685527202585, -2.1483685527202585, -2.1483685527202154
# V=84.21: Energies: -5.0430974700327553, -5.0430974700327553, -5.0430974700327553, -5.0430974700327553, -5.0221420443736653, -5.0221420443736502, -5.0221420443736502, -3.6014921960352013, -3.6014921960351320, -3.6014921960351320, -3.6014921960351320, -3.6014921960351320, -2.9306380595402897, -2.9306380595402897, -2.9306380595402897, -2.9306380595402897, -2.9225419393803644, -2.9225419393803644, -2.9225419393803067, -2.5548713327303041, -2.5548713327303041, -2.5548713327303041, -2.5548713327303041, -2.5548713327302943, -2.5548713327302943, -2.5548713327302943, -2.5548713327302943, -2.1299266635129825, -2.1299266635129825, -2.1299266635129825, -2.1299266635129825, -2.1299266635129284
# V=94.74: Energies: -5.0272171360271685, -5.0272171360271685, -5.0272171360271685, -5.0272171360271685, -5.0088022779890702, -5.0088022779890702, -5.0088022779890462, -3.5863454104591295, -3.5863454104590966, -3.5863454104590966, -3.5863454104590966, -3.5863454104590966, -2.9194513924038756, -2.9194513924038756, -2.9194513924038756, -2.9194513924038756, -2.9121711514801070, -2.9121711514800048, -2.9121711514800048, -2.5433103727290445, -2.5433103727290445, -2.5433103727290445, -2.5433103727290445, -2.5433103727290378, -2.5433103727290378, -2.5433103727290378, -2.5433103727290378, -2.1155617426797080, -2.1155617426796618, -2.1155617426796618, -2.1155617426796618, -2.1155617426796618
# V=105.26: Energies: -5.0144890525500783, -5.0144890525500783, -5.0144890525500783, -5.0144890525500783, -4.9980686164380277, -4.9980686164380277, -4.9980686164380277, -3.5742057605970672, -3.5742057605970672, -3.5742057605970672, -3.5742057605970672, -3.5742057605970192, -2.9104710403622267, -2.9104710403622267, -2.9104710403622267, -2.9104710403622267, -2.9038591218271481, -2.9038591218271463, -2.9038591218271463, -2.5340348391225787, -2.5340348391225787, -2.5340348391225787, -2.5340348391225787, -2.5340348391225045, -2.5340348391225045, -2.5340348391225045, -2.5340348391225045, -2.1040565835436422, -2.1040565835435241, -2.1040565835435241, -2.1040565835435241, -2.1040565835435241
# V=115.79: Energies: -5.0040594051337282, -5.0040594051337282, -5.0040594051337282, -5.0040594051337282, -4.9892455706761334, -4.9892455706761334, -4.9892455706760455, -3.5642588146007430, -3.5642588146007244, -3.5642588146007244, -3.5642588146007244, -3.5642588146007244, -2.9031030552895487, -2.9031030552895487, -2.9031030552895487, -2.9031030552895487, -2.8970481557102614, -2.8970481557102614, -2.8970481557102001, -2.5264280953616534, -2.5264280953616534, -2.5264280953616534, -2.5264280953616534, -2.5264280953613376, -2.5264280953613376, -2.5264280953613376, -2.5264280953613376, -2.0946346109654463, -2.0946346109654361, -2.0946346109654361, -2.0946346109654361, -2.0946346109654361
# V=126.32: Energies: -4.9953571873431128, -4.9953571873431128, -4.9953571873431128, -4.9953571873431128, -4.9818648384205710, -4.9818648384205710, -4.9818648384204618, -3.5559598253846176, -3.5559598253845994, -3.5559598253845994, -3.5559598253845994, -3.5559598253845994, -2.8969490745056192, -2.8969490745056192, -2.8969490745056192, -2.8969490745056192, -2.8913653090438896, -2.8913653090437084, -2.8913653090437084, -2.5200770074907717, -2.5200770074907717, -2.5200770074907717, -2.5200770074907717, -2.5200770074906709, -2.5200770074906709, -2.5200770074906709, -2.5200770074906709, -2.0867770594620203, -2.0867770594620203, -2.0867770594620203, -2.0867770594620203, -2.0867770594619728
# V=136.84: Energies: -4.9879860657290402, -4.9879860657290402, -4.9879860657290402, -4.9879860657290402, -4.9755995649286628, -4.9755995649286628, -4.9755995649286362, -3.5489306590951220, -3.5489306590950451, -3.5489306590950451, -3.5489306590950451, -3.5489306590950451, -2.8917319533748613, -2.8917319533748613, -2.8917319533748613, -2.8917319533748613, -2.8865517350985774, -2.8865517350985774, -2.8865517350985108, -2.5146944017398982, -2.5146944017398982, -2.5146944017398982, -2.5146944017398982, -2.5146944017398374, -2.5146944017398374, -2.5146944017398374, -2.5146944017398374, -2.0801241949901632, -2.0801241949901632, -2.0801241949901632, -2.0801241949901632, -2.0801241949900975
# V=147.37: Energies: -4.9816623348796325, -4.9816623348796325, -4.9816623348796325, -4.9816623348796325, -4.9702146996573138, -4.9702146996573138, -4.9702146996572507, -3.5429006308311930, -3.5429006308310802, -3.5429006308310802, -3.5429006308310802, -3.5429006308310802, -2.8872529259878807, -2.8872529259878807, -2.8872529259878807, -2.8872529259878807, -2.8824221511461814, -2.8824221511461814, -2.8824221511460606, -2.5100744639783881, -2.5100744639783881, -2.5100744639783881, -2.5100744639783881, -2.5100744639782295, -2.5100744639782295, -2.5100744639782295, -2.5100744639782295, -2.0744187167725743, -2.0744187167725743, -2.0744187167725743, -2.0744187167725743, -2.0744187167724877
# V=157.89: Energies: -4.9761775642681645, -4.9761775642681645, -4.9761775642681645, -4.9761775642681645, -4.9655368855143802, -4.9655368855143793, -4.9655368855143793, -3.5376708760622808, -3.5376708760622808, -3.5376708760622808, -3.5376708760622808, -3.5376708760621938, -2.8833657313795644, -2.8833657313795644, -2.8833657313795644, -2.8833657313795644, -2.8788404383890822, -2.8788404383890822, -2.8788404383890662, -2.5060658351300527, -2.5060658351300527, -2.5060658351300527, -2.5060658351300527, -2.5060658351300131, -2.5060658351300131, -2.5060658351300131, -2.5060658351300131, -2.0694717229889918, -2.0694717229888639, -2.0694717229888639, -2.0694717229888639, -2.0694717229888639
# V=168.42: Energies: -4.9713751859707598, -4.9713751859707598, -4.9713751859707598, -4.9713751859707598, -4.9614354678016506, -4.9614354678013655, -4.9614354678013655, -3.5330920153194341, -3.5330920153193621, -3.5330920153193621, -3.5330920153193621, -3.5330920153193621, -2.8799603530752274, -2.8799603530752274, -2.8799603530752274, -2.8799603530752274, -2.8757043495253996, -2.8757043495253778, -2.8757043495253778, -2.5025547199059170, -2.5025547199059170, -2.5025547199059170, -2.5025547199059170, -2.5025547199058100, -2.5025547199058100, -2.5025547199058100, -2.5025547199058100, -2.0651414000165844, -2.0651414000165418, -2.0651414000165418, -2.0651414000165418, -2.0651414000165418
# V=178.95: Energies: -4.9671353086753491, -4.9671353086753491, -4.9671353086753491, -4.9671353086753491, -4.9578101104856032, -4.9578101104856032, -4.9578101104854548, -3.5290496651194956, -3.5290496651194916, -3.5290496651194916, -3.5290496651194916, -3.5290496651194916, -2.8769524483612368, -2.8769524483612368, -2.8769524483612368, -2.8769524483612368, -2.8729355900900315, -2.8729355900900169, -2.8729355900900169, -2.4994539152176305, -2.4994539152176305, -2.4994539152176305, -2.4994539152176305, -2.4994539152175732, -2.4994539152175732, -2.4994539152175732, -2.4994539152175732, -2.0613192115645878, -2.0613192115645878, -2.0613192115645878, -2.0613192115645878, -2.0613192115644758
# V=189.47: Energies: -4.9633645723967312, -4.9633645723967312, -4.9633645723967312, -4.9633645723967312, -4.9545824852006124, -4.9545824852006124, -4.9545824852005493, -3.5254547575960182, -3.5254547575959649, -3.5254547575959649, -3.5254547575959649, -3.5254547575959649, -2.8742762728054867, -2.8742762728054867, -2.8742762728054867, -2.8742762728054867, -2.8704731923774758, -2.8704731923774758, -2.8704731923773910, -2.4966954716190628, -2.4966954716190628, -2.4966954716190628, -2.4966954716190628, -2.4966954716188670, -2.4966954716188670, -2.4966954716188670, -2.4966954716188670, -2.0579206790990496, -2.0579206790990496, -2.0579206790990496, -2.0579206790990496, -2.0579206790990057
# V=200.00: Energies: -4.9599891942213068, -4.9599891942213068, -4.9599891942213068, -4.9599891942213068, -4.9516905517005778, -4.9516905517005601, -4.9516905517005601, -3.5222369046660504, -3.5222369046659634, -3.5222369046659634, -3.5222369046659634, -3.5222369046659634, -2.8718798222469935, -2.8718798222469935, -2.8718798222469935, -2.8718798222469935, -2.8682689736278189, -2.8682689736277922, -2.8682689736277922, -2.4942256577430020, -2.4942256577430020, -2.4942256577430020, -2.4942256577430020, -2.4942256577427604, -2.4942256577427604, -2.4942256577427604, -2.4942256577427604, -2.0548790663944079, -2.0548790663940757, -2.0548790663940757, -2.0548790663940757, -2.0548790663940757
